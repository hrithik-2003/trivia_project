# %%
import sys
import os

# Add parent directory to sys.path to access `fakeyou` package
sys.path.append(os.path.abspath(".."))

# %%
import Voice.fakeyou.fakeyou2 as fymod
from importlib import reload
import Voice.fakeyou.util.service as service_module

reload(service_module)
reload(fymod)

# Create an instance of the AsyncFakeYou class
fy = fymod.FakeYou2()

# Call the login method with email and password and await the result
login = fy.login("dumpmedia3@gmail.com", "hri2.03.0")

# Print the username of the logged-in user
print("Logged in as:", login.username)

# Call the list_voices method and await the result
voices = fy.get_voices()
# Out:
# URL: https://api.fakeyou.com/session
# Logged in as: kaththi03
# URL: https://api.fakeyou.com/tts/list

# %%
token = ''

print("Available voices:")
for modelTokens, title in zip(voices.modelTokens, voices.title):
     if 'Sexy Beatrice (British Accent)' in title:
        print(f"Title {title}: {modelTokens}")
        token = modelTokens
# Out:
# Available voices:
# Title Sexy Beatrice (British Accent): weight_cvwnagsfbb4v0fag8c84sqat1

# %%
result = fy.say("Fuck this World, Fuck the economy, Fuck the market, fuck everything.", tts_model_token=token)
# Out:
# URL: https://api.fakeyou.com/tts/job/jinf_4z6gp3rcpcrxp9nxrcqx7984jp5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 result = fy.say("Fuck this World, Fuck the economy, Fuck the market, fuck everything.", tts_model_token=token)
#
# File c:\Users\Hrithik\OneDrive\Documents\AI\Fnite\trivia_quiz_project\Voice\fakeyou\fakeyou2.py:77, in say(self, text, tts_model_token)
#      74 def say(self, text: str, tts_model_token: str):
#      75     return self.tts_poll(self.make_tts_job(text=text, tts_model_token=tts_model_token))
# ---> 77 def tts_status(self, ijt: str):
#      78     return self.get(f"/tts/job/{ijt}").json()["state"]["status"]
#      80 def get_tts_leaderboard(self):
#
# File c:\Users\Hrithik\OneDrive\Documents\AI\Fnite\trivia_quiz_project\Voice\fakeyou\fakeyou2.py:47, in FakeYou2.tts_poll(self, ijt)
#      45 def tts_poll(self, ijt: str):
#      46     while True:
# ---> 47         ijt_data = self.get(f"/tts/job/{ijt}").json()
#      48         wav = Wav(ijt_data)
#      49         if wav.status in ["started", "pending"]:
#
# File c:\Users\Hrithik\OneDrive\Documents\AI\Fnite\trivia_quiz_project\Voice\fakeyou\util\service.py:35, in Service.get(self, path, params)
#      31     url = self.api(path)
#      33 #print('URL:', url)
# ---> 35 response = self.__session.get(
#      36     url,
#      37     params=params,
#      38     proxies=self.proxies
#      39 )
#      40 return handle_response(response)
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Hrithik\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
with open("output/output.wav", "wb") as f:
    f.write(result.content)
